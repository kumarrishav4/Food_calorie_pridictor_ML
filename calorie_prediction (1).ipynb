# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/Food detction/nutrition.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# name            0
# serving_size    0
# calories        0
# total_fat       0
#                ..
# alcohol         0
# ash             0
# caffeine        0
# theobromine     0
# water           0
# Length: 77, dtype: int64

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data.shape
# Out:
# (8789, 76)

# %%
import numpy as np
# Ensuring all values in the 'saturated_fat' column are strings before applying string operations
data['saturated_fat'] = data['saturated_fat'].astype(str)

# Removing 'g' and converting to float
data['saturated_fat'] = (
    data['saturated_fat']
    .str.replace('g', '', regex=False)  # Remove 'g'
    .replace(['', '-', '--'], np.nan)
    .astype(float)  # Convert to float
)

# Imputing missing values with the median
data['saturated_fat'].fillna(data['saturated_fat'].median(), inplace=True)

# Verifying the changes
data['saturated_fat'].head()
# Out:
# <ipython-input-13-0485a75e6872>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['saturated_fat'].fillna(data['saturated_fat'].median(), inplace=True)
# 0    2.2
# 1    6.2
# 2    2.2
# 3    0.4
# 4    1.2
# Name: saturated_fat, dtype: float64

# %%
data.head()
# Out:
#               name serving_size  calories total_fat  saturated_fat  \
# 0       Cornstarch        100 g       381      0.1g            2.2
# 1     Nuts, pecans        100 g       691       72g            6.2
# 2    Eggplant, raw        100 g        25      0.2g            2.2
# 3   Teff, uncooked        100 g       367      2.4g            0.4
# 4  Sherbet, orange        100 g       144        2g            1.2
#
#   cholesterol    sodium  choline     folate folic_acid  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
data.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
# Function to clean units and convert to float
def clean_numeric_column(column):
    return (
        column.astype(str)
        .str.replace(r'[^\d.-]', '', regex=True)
        .replace('', np.nan)
        .astype(float)
    )
# Apply the cleaning function to all columns with numeric-like data in 'data'
for col in data.columns:
    try:
        data[col] = clean_numeric_column(data[col])
    except Exception as e:
        pass
# Confirming that columns in 'data' are now cleaned and numeric
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   float64
#  2   calories                     8789 non-null   float64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   float64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
#  8   folate                       8789 non-null   float64
#  9   folic_acid                   8789 non-null   float64
#  10  niacin                       8789 non-null   float64
#  11  pantothenic_acid             8789 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

if 'name' in data.columns:
    # Using label encoding for simplicity (alternatively, one-hot encoding could be applied)
    from sklearn.preprocessing import LabelEncoder
    label_encoder = LabelEncoder()
    data['name'] = label_encoder.fit_transform(data['name'])

# Correctly selecting multiple columns using a list
X = data[['total_fat', 'cholesterol', 'sodium', 'calcium',
          'sugars', 'saturated_fat', 'serving_size', 'vitamin_c']]  # Select relevant features
y = data['calories']  # Target column


# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Split the PCA-reduced dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest Regressor": RandomForestRegressor(random_state=42),
    "Support Vector Regressor (SVR)": SVR(kernel='rbf', C=1.0, epsilon=0.1),
    "K-Nearest Neighbors Regressor (KNN)": KNeighborsRegressor(n_neighbors=5)
}

# Train and evaluate models
results = {}

for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate performance
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Store results
    results[model_name] = {"MSE": mse, "MAE": mae, "R2 Score": r2}

# Convert results to a DataFrame for better visualization
import pandas as pd
results_df = pd.DataFrame(results).T
results_df.head()
# Out:
#                                              MSE        MAE  R2 Score
# Linear Regression                    7057.799081  62.463062  0.744997
# Random Forest Regressor              2675.821597  29.849530  0.903321
# Support Vector Regressor (SVR)       9795.256237  62.826575  0.646091
# K-Nearest Neighbors Regressor (KNN)  3654.254653  34.305119  0.867970

# %%
# Calculate training performance metrics for each model
training_results = {}

for model_name, model in models.items():
    # Predictions on training data
    y_train_pred = model.predict(X_train)

    # Evaluate training performance
    mse = mean_squared_error(y_train, y_train_pred)
    mae = mean_absolute_error(y_train, y_train_pred)
    r2 = r2_score(y_train, y_train_pred)

    # Store results
    training_results[model_name] = {"Train MSE": mse, "Train MAE": mae, "Train R2 Score": r2}

training_results_df = pd.DataFrame(training_results).T

# Combine training and testing results for comparison

training_results_df.head()
# Out:
#                                        Train MSE  Train MAE  Train R2 Score
# Linear Regression                    6872.144412  62.167054        0.764183
# Random Forest Regressor               380.699858  11.189260        0.986936
# Support Vector Regressor (SVR)       9913.764636  62.646223        0.659810
# K-Nearest Neighbors Regressor (KNN)  2469.658296  28.402759        0.915254

# %%
import pickle

# Save the Random Forest model (or any other model you prefer)
with open("calorie_prediction.pkl", 'wb') as file:
    pickle.dump(models["Random Forest Regressor"], file)

print("Calorie Prediction model saved successfully.")
# Out:
# Calorie Prediction model saved successfully.

# %%
import pickle

# Save the scaler
with open("scaler.pkl", "wb") as scaler_file:
    pickle.dump(scaler, scaler_file)
